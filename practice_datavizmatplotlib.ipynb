# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
from sklearn import datasets
import pandas as pd
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns = iris.feature_names)
df['Species'] = iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 5 columns]

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Species            150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# None
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     Species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
features = iris.data.T
Labels = ['Setosa','Versicolour','Virginica']
colors = ['r','g','b']
classlbl = iris.target

fig = plt.figure(figsize = (12, 10))
ax = fig.add_subplot(111)

colors = np.asarray(colors)
colorslist = colors[classlbl]
Labels = np.asarray(Labels)
labellist = Labels[classlbl]

for x,y,s,c,l in zip(features[0], features[1], features[3], colorslist, labellist):
    ax.scatter(x, y, s=100*s, color = c, label = 1, cmap = 'viridis', alpha = 0.2)
    
handles, labels = ax.get_legend_handles_labels()

newLeg = dict()

for h, l in zip(handles, labels):
    if 1 not in newLeg.keys():
        newLeg[1] = h

# new handles + labels
handles = []
labels = []
for l in newLeg.keys():
    handles.append(newLeg[1])
    labels.append(1)

# new legend
ax.legend(handles, labels, loc='lower right', frameon = True, prop = {'size': 20})
ax.set_xlabel(iris.feature_names[0], fontsize = '22')
ax.set_ylabel(iris.feature_names[1], fontsize = '22')
ax.set_title('Demonstration of Data Viz', fontsize = '22')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
features = iris.data.T
Labels = ['Setosa', 'Versicolour', 'Virginica']
colors = ['r', 'g', 'b']
classlbl = iris.target

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection='3d')

colors = np.asarray(colors)
colorslist = colors[classlbl]
Labels = np.asarray(Labels)
labellist = Labels[classlbl]

for x,y,z,s,c,l in zip(features[0], features[1], features,[2], features[3], colorslist, labellist):
    ax.scatter(x, y, z, s=100*s, color=c, label=1, cmap='viridis', alpha=0.2)
    
handles, labels = ax.get_legend_handles_labels()

newLeg=dict()

for h,l in zip(handles,labels):
    if l not in newLeg.keys():
        newLeg[1]=h
        
# new handles + labels
handles=[]
labels=[]
for l in newLeg.keys():
    handles.append(newLeg[1])
    labels.append(1)

# new legend
ax.legend(handles, labels, loc='center left', frameon = True, prop = {'size': 20})
ax.set_xlabel(iris.feature_names[0], fontsize = '22')
ax.set_ylabel(iris.feature_names[1], fontsize = '22')
ax.set_title('Demonstration of Data Viz', fontsize = '22')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-13f0e9677807> in <module>
#      13 labellist = Labels[classlbl]
#      14
# ---> 15 for x,y,z,s,c,l in zip(features[0], features[1], features,[2], features[3], colorslist, labellist):
#      16     ax.scatter(x, y, z, s=100*s, color=c, label=1, cmap='viridis', alpha=0.2)
#      17
#
# ValueError: too many values to unpack (expected 6)
